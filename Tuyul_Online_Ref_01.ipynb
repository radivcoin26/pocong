# %% [markdown]
# ## <img src='https://radivcoin.com/wp-content/uploads/2022/02/logo-fix.png' height="50" alt="iceWM" />
# ##<font text-align='center'> ___PC Online Embah Google___ </font>
# ##<font text-align='center'> ___Buat Tuyul Viwer Video Online___ </font>
#
# #`SysTools(`<font size="3px" color="#f8f800">`noVNC`</font>, <font size="3px" color="#aaabad">`Crash Colab`, <font size="3px" color="#aaabad">`Script Tambahan`,<font size="3px" color="#aaabad">`49 Token Ngerok`, <font size="3px" color="#aaabad">`Check VM's Status`</font>) <font size="3px" color="#aaabad">`Check VM's Status`</font>)

# %% [markdown]
# ## __noVNC Embah Google___

# %%
#@markdown <br><center><img src='https://radivcoin.com/wp-content/uploads/2022/02/logo-fix.png' height="100" alt="iceWM"/></center>
#@markdown <center><h3>PC Online Embah Google</h3></center><br>
import os
import random
import string
import urllib.request
from IPython.display import HTML, clear_output
import time

#####################################

TOKEN_LIST = ["1iNuxP04mmK6SL66Vo6z34R1my3_kWh6KZAW9SduTqhq1Ko2",
"1iVpQYolb1yM261P5coP9uBmqSy_LLt6WohJWDLYmDdbCfga",
"1iVpL6wFta7YFXG8n5iBRMOIW6a_5oi5CzX7XB9sT1bhv8hF9",
"1iVpFUwrHCVjRe09SPoEElr1MCD_6uUm1HWjxfc6zbbfrJs32",
"1hHfwHoeB5sft9UBX8Xixa7PV17_3zQj6fTGGzZmntoSBtNKk",
"1hIC9jFLfFXCD2QRJUhoNinIpiG_2cQnTZEV4yrUUQAw81J61",
"1hIBc9OUpPAo10AMMeS9YoPFeRx_3KUtLibSjTGfVZdxRQTRN",
"1hHMx4M7dy2Zf5oY2VNTOxYvuKk_3CgYUgXXg8MjuEBkDdcSr",
"1hIAkM6UKxzbA27qjaPC46aJJRY_3uBeqnNGNPo6ZR9iGzgzf",
"1hHh9P5pKOakbpDtyMFRc94uyeF_3brXNHN1CakdvL8enpgxj",
"1hIy9UXTnjqhvR7Ke3AYs9Noz3l_29e2Ude2rGPLivp8Pvzd9",
"1hVonigovnXs4mQLpQ7QtXcDTQy_5oUVRA1zUomfJJLkgvSkb",
"1hVpMIG0CjpH5ZqxmXvyzNDoW8v_84d6xYQbdfjzu1U61kwvW",
"1hVpUb8EYwCCA41MxVDRt4l3iXO_y855Czw2rcuEhpnvFwPm",
"1hVph5D25c44WISY8vUiZyqUqOs_5HbRfULEVaQpZ4uuDb7WW",
"1hXMKEOwtGy5bIHDhwjLJthDCat_7ELHueiUPhijYFMixbqYo",
"1hYgSjq53wCPkwJYkSRmRzEl1c3_8bmCmXoC4oEBgHw1CVKY",
"1hYgXbwb82S5JxhpNuOt3GP9fzN_Qrv3jzM3axjrPncKkeHS",
"1hYhNrBllwcyFFs5caNqwnYwcX2_4GE8hANaRp2SqzRFt3Ur3",
"1hhUVxZWxjANfpZniQm3wWpx0TI_2CDicC6aBgYUj52coX6bu",
"1hhUgEaXVyXBapgRz0UAkDAIXyM_4tgz18C42JteEseFk1t3F",
"1hjFthfgu7ClWr2S8ODahFDBdmM_7MnyfK953dAesWz2jS5jy",
"1iWEGgXyuhWBuO0st6jrraYsMvV_3gdiBjyUpUQEqrLYYfFAs",
"1iWEL4i9Ckc2Rb2wSoKSxk5k656_6odmDj4uX5Jg6SGcVWzSP",
"1iWEPRCzx06E09Kv10Pe7NFCL7q_3tLZeXvvuUXfVP7MCNtUQ",
"1iWRe876KJbpdiQvhO2XJLwIRu1_7MCmzizYAjSyx8zTxzL81",
"1iWTiNwhsoAwtQS1WT4TupbOk69_33rQbbXNvGzPC7QfVzF9o",
"1iWUfohPxvxGHp0uuf0x4pqAjaZ_5K774QRWvNbvotBQbxUuY",
"1ih54yQ1N8vaMiJLiFnevaj6Mji_4iBE93NNsj2MHyZKMcznw",
"1ih5GJp4XjLgQZ7fsF9MnXtMnUU_4FtzMbgdgNj77hcqpWyhu",
"1ih5OeOJ7X7iaJ7b4XR2zmyMBPL_2nHwr8Cb8dj5MEdJUS9rp",
"1ih5Wh8TmDEnMULhaj2jNpfL6TS_2AWXkPwNDnqpthXrnuJzj",
"1ih5dfFqnfETG7g4JjZAE9ekEZC_6ji6pDY8Zd5PpUgBeDZUE",
"1ih5oaQFXdlzxrSYv0M7t22oXAc_2XC6ascuV7Pm4Kj8aGeiZ",
"1ih5tCb3HJYaLHuZw7Cxn9wyMqq_EWe8WQru5CD8jgKd61Kw",
"1ih60XZEyWqDchD8JBryu2RNdnK_4Vxb1WqhikNXVrMoGLcyn",
"1ih64HYeC9RVoFRhV9kiqvlNV5e_4JCmRQJBmhenjDpGCu9nq",
"1ih6AIS3o3klPNA9FYcbdH83ECf_5G5wgX2cVtwCJweD8qHwQ",
"1ih6GBRdVyWQYtfxZT8iUZHcoYb_6oRDCy1HtmXNVsYeCcyoR",
"1ih6LMu0JCcEnYYCftG0Oa2G8gK_45LHm9gGcfRVxn6Yg7uqq",
"1ih6RKqz9s0UDHlOtttL9h2eHiX_jPUdonbDnwqqqYW8Wrpp",
"1ih6Ws8WAnLxbAYUrK4gnGN7Qqw_H8gju711smviiRH2E48p",
"1ih6cHiK8XSzSaI9IXa62Ufv3Wj_54zcBXq5oogmxqcx1TfYQ",
"1ih6gT3lWxNP7hGbgNpWzv6I5w1_5u6TGkkLaBFTEpFJMYKjG",
"1ih6lWGj5sZ8VvfA6G15URGHyEb_5HjpxPG3NwichMSjjcT59",
"1ih6qnzNVVqU2AA0TUWnw6mKNho_E2HVZyawkr126pbeqUvk",
"1ih6v2p9plBFgaabCvHv9jUTtfA_7t7hrP565GfEtucd68dzN",
"2769iVul2UCYpeTA6K1YtGDICFl_56dJqtqD1mnm9HpbB1asB",
"276Cu49xto7BgjP4MUtu4AKm8pw_3FitixyygHfk23zFrG1vf"]
USE_FREE_TOKEN = False # @param {type:"boolean"}
TOKEN = "Acak_Token" #@param ] ["Acak_Token",""]
if TOKEN == "Acak_Token":
        TOKEN = random.choice(TOKEN_LIST);
REGION_LIST = ["us", "eu", "ap", "au", "sa", "jp", "in"]
REGION = "Acak_Region" #@param ] ["Acak_Region","US", "EU", "AP", "AU", "SA", "JP", "IN"]
if REGION == "Acak_Region":
  REGION = random.choice(REGION_LIST);
PORT_FORWARD = "ngrok" #@param ] ["ngrok", "localhost", "argotunnel"]

HOME = os.path.expanduser("~")
runW = get_ipython()

if not os.path.exists(f"{HOME}/.ipython/ocr.py"):
    hCode = "https://raw.githubusercontent.com/radivcoin26/" \
                "pocong/main/res/ocr.py"
    urllib.request.urlretrieve(hCode, f"{HOME}/.ipython/ocr.py")

from ocr import (
    runSh,
    loadingAn,
    PortForward_wrapper,
    displayUrl,
    findProcess,
    CWD,
    textAn,
)

# github latest releases tag define
def latestTag(link):
  import re
  from urllib.request import urlopen
  htmlF = urlopen(link+"/releases/latest").read().decode('UTF-8')
  return re.findall(r'.+\/tag\/([.0-9A-Za-z]+)".+/', htmlF)[0]


loadingAn()

os.makedirs("tools/noVnc", exist_ok=True)

# password ganarate
try:
  print(f"Found old password! : {password}")
except:
  password = ''.join(random.choice(string.ascii_letters + string.digits) for i in range(20))


clear_output()
if not findProcess("Xtightvnc", ":1"):
  textAn("Antosan Sakedap kiranglangkuk 60 Detik. Éta nuju disiapkeun pikeun VNC ......")
  os.makedirs(f'{HOME}/.vnc', exist_ok=True)
  runW.system_raw('apt update -y')
  runW.system_raw('apt install -y icewm firefox tightvncserver autocutsel xterm')

  runW.system_raw(rf'echo "{password}" | vncpasswd -f > ~/.vnc/passwd')
  data = """
#!/bin/bash
xrdb $HOME/.Xresources
xsetroot -solid black -cursor_name left_ptr
autocutsel -fork
icewm-session &
"""
  with open(f'{HOME}/.vnc/xstartup', 'w+') as wNow:
    wNow.write(data)
  os.chmod(f'{HOME}/.vnc/xstartup', 0o755)
  os.chmod(f'{HOME}/.vnc/passwd', 0o400)
  
  runSh('sudo vncserver :1 -geometry 1440x870 -economictranslate -dontdisconnect &', 
        shell=True)

  BASE_URL = "https://github.com/geek1011/easy-novnc"
  LATEST_TAG = latestTag(BASE_URL)
  output_file = "tools/noVnc/easy-noVnc_linux-64bit"
  file_name = f"easy-novnc_linux-64bit"
  urlF = f"{BASE_URL}/releases/download/{LATEST_TAG}/{file_name}"
  try:
    urllib.request.urlretrieve(urlF, output_file)
  except OSError:
    pass
  os.chmod(output_file, 0o755)

if not findProcess("easy-noVnc_linux-64bit", '--addr "0.0.0.0:6080"'):
  cmdDo = "./easy-noVnc_linux-64bit --addr 0.0.0.0:6080 --port 5901" \
    " &"
  runSh(cmdDo, 
        cd="tools/noVnc/",
        shell=True)


# START_SERVER
# Ngrok region 'us','eu','ap','au','sa','jp','in'
clear_output()
Server = PortForward_wrapper(PORT_FORWARD, TOKEN, USE_FREE_TOKEN, [['vnc', 6080, 'http']], REGION.lower(), 
               [f"{HOME}/.ngrok2/noVncFast.yml", 4455])

data = Server.start('vnc', displayB=False)
# clear_output()
displayUrl(data, pNamU='noVnc : ',
            EcUrl=f'/vnc.html?autoconnect=true&password={password}&path=vnc&resize=scale&reconnect=true&show_dot=true')

# %%
# ============================= FORM ============================= #
# @markdown #### ⬅️ Install File Aplikasi Tambahan Khusus
# !lscpu
# !yes '\n' | add-apt-repository ppa:saiarcot895/chromium-dev 
# !apt-get update
# !apt-get install chromium-browser gconf-service libasound2 libatk1.0-0 libc6 libcairo2 libcups2 libdbus-1-3 libexpat1 libfontconfig1 libgcc1 libgconf-2-4 libgdk-pixbuf2.0-0 libglib2.0-0 libgtk-3-0 libnspr4 libpango-1.0-0 libpangocairo-1.0-0 libstdc++6 libx11-6 libx11-xcb1 libxcb1 libxcomposite1 libxcursor1 libxdamage1 libxext6 libxfixes3 libxi6 libxrandr2 libxrender1 libxss1 libxtst6 ca-certificates fonts-liberation libappindicator1 libnss3 lsb-release xdg-utils wget
# !pip install pyppeteer2
# !pip install pyppeteer_stealth
# !pip install fake-useragent
# !wget https://raw.githubusercontent.com/radivcoin26/pocong/main/res/ley.sh 
# !chmod +x ley.sh
clear_output()
# ================================================================ #

# %%
# ============================= FORM ============================= #
# @markdown #### ⬅️ Check VM's Status
Check_IP = True 
Loop_Check = True  #@param {type:"boolean"}
Loop_Interval = 3600 
# ================================================================ #

import time, requests
from IPython.display import clear_output

Loop = True
try:
    while Loop == True:
        clear_output(wait=True)
        # !top -bcn1 -w512
        sessionIP = f"\nYour Public IP: {requests.get('http://ip.42.pl/raw').text}:12121"
        if Check_IP: 
            print(sessionIP)             
        print("====")
        if Loop_Check == False:
            Loop = False
        else:
            time.sleep(Loop_Interval)
except:
  clear_output()

# %% [markdown]
# ## __Crash Colab to clear all RAM__

# %%
#@title ← ឵឵ ឵(Token NGROK VPN Gagal) ← ឵឵ ឵Run this cell to crash your current Runtime if you're low on memory
#@markdown <i>After crashing, you'll have access to all the preoccupied storage. Then it'll help you for Rclone cache file storage increase (Recommend for a first run this cell) </i>
some_str = ' ' * 5120000000000

# %%
#@markdown <br><center><img src='https://upload.wikimedia.org/wikipedia/commons/thumb/d/da/Google_Drive_logo.png/600px-Google_Drive_logo.png' height="50" alt="Gdrive-logo"/></center>
#@markdown <center><h3>Mount Gdrive to /content/drive</h3></center><br>
MODE = "MOUNT" #@param ["MOUNT", "UNMOUNT"]
#Mount your Gdrive! 
from google.colab import drive
drive.mount._DEBUG = False
if MODE == "MOUNT":
  drive.mount('/content/drive', force_remount=True)
elif MODE == "UNMOUNT":
  try:
    drive.flush_and_unmount()
  except ValueError:
    pass
  get_ipython().system_raw("rm -rf /root/.config/Google/DriveFS")

# %% [markdown]
# ## __Script Tambahan__

# %%
#@title ← ឵឵ ឵(Script Buat Nuyul dailimotion.com)Tinggal Copy Paste

COLAB CHROMIUM
https://teknosimple.com/DND20DU2SBwr

SET !ERRORIGNORE YES
SET !REPLAYSPEED FAST
WAIT SECONDS=1
URL GOTO=https://www.dailymotion.com/
URL GOTO=https://dai.ly/x8g3eec
WAIT SECONDS=31
SET !ERRORIGNORE YES
SET !REPLAYSPEED FAST
WAIT SECONDS=2
URL GOTO=https://www.dailymotion.com/
URL GOTO=https://dai.ly/x8g68vo
WAIT SECONDS=32
SET !ERRORIGNORE YES
SET !REPLAYSPEED FAST
WAIT SECONDS=3
URL GOTO=https://www.dailymotion.com/
URL GOTO=https://dai.ly/x8g20u0
WAIT SECONDS=33
SET !ERRORIGNORE YES
SET !REPLAYSPEED FAST
WAIT SECONDS=4
URL GOTO=https://www.dailymotion.com/
URL GOTO=https://dai.ly/x8g205q
WAIT SECONDS=34
SET !ERRORIGNORE YES
SET !REPLAYSPEED FAST
WAIT SECONDS=5
URL GOTO=https://www.dailymotion.com/
URL GOTO=https://dai.ly/x8g205p
WAIT SECONDS=35
SET !ERRORIGNORE YES
SET !REPLAYSPEED FAST
WAIT SECONDS=6
URL GOTO=https://www.dailymotion.com/
URL GOTO=https://dai.ly/x8g7ji1
WAIT SECONDS=15
SET !ERRORIGNORE YES
SET !REPLAYSPEED FAST
WAIT SECONDS=7
URL GOTO=https://www.dailymotion.com/
URL GOTO=https://dai.ly/x8g1yfv
WAIT SECONDS=36
SET !ERRORIGNORE YES
SET !REPLAYSPEED FAST
WAIT SECONDS=7
URL GOTO=https://www.dailymotion.com/
URL GOTO=https://dai.ly/x8g1yfu
WAIT SECONDS=37
REFRESH
WAIT SECONDS=5

# %%
#@title ← ឵឵ ឵(Script Buat Nuyul rumble.com)Tinggal Copy Paste
VERSION BUILD=1011 RECORDER=CR
URL GOTO=https://rumble.com/
WAIT SECONDS=3
EVENT TYPE=MOUSEDOWN SELECTOR="HTML>BODY>HEADER>DIV>FORM>BUTTON>svg" BUTTON=0
EVENT TYPE=CLICK SELECTOR="HTML>BODY>HEADER>DIV>FORM>BUTTON>svg" BUTTON=0
EVENT TYPE=MOUSEDOWN SELECTOR="HTML>BODY>HEADER>DIV>FORM>INPUT" BUTTON=0
EVENT TYPE=CLICK SELECTOR="HTML>BODY>HEADER>DIV>FORM>INPUT" BUTTON=0
EVENT TYPE=KEYPRESS SELECTOR="HTML>BODY>HEADER>DIV>FORM>INPUT" KEY=20
EVENTS TYPE=KEYPRESS SELECTOR="HTML>BODY>HEADER>DIV>FORM>INPUT" CHARS="SEBA BADUY 2017 TRAILER 1"
EVENT TYPE=CLICK SELECTOR="HTML>BODY>HEADER>DIV>FORM>BUTTON>svg" BUTTON=0
WAIT SECONDS=3
EVENT TYPE=CLICK SELECTOR="HTML>BODY>MAIN>DIV>DIV:nth-of-type(2)>DIV>OL>LI>ARTICLE" BUTTON=0
EVENT TYPE=CLICK SELECTOR="HTML>BODY>MAIN>DIV>DIV:nth-of-type(2)>DIV>OL>LI>ARTICLE>A" BUTTON=0
EVENT TYPE=CLICK SELECTOR="#vid_v1x0ods>DIV>DIV" BUTTON=0
WAIT SECONDS=80
REFRESH
URL GOTO=https://rumble.com/
WAIT SECONDS=3
EVENT TYPE=MOUSEDOWN SELECTOR="HTML>BODY>HEADER>DIV>FORM>BUTTON>svg" BUTTON=0
EVENT TYPE=CLICK SELECTOR="HTML>BODY>HEADER>DIV>FORM>BUTTON>svg" BUTTON=0
EVENT TYPE=MOUSEDOWN SELECTOR="HTML>BODY>HEADER>DIV>FORM>INPUT" BUTTON=0
EVENT TYPE=CLICK SELECTOR="HTML>BODY>HEADER>DIV>FORM>INPUT" BUTTON=0
EVENT TYPE=KEYPRESS SELECTOR="HTML>BODY>HEADER>DIV>FORM>INPUT" KEY=20
EVENTS TYPE=KEYPRESS SELECTOR="HTML>BODY>HEADER>DIV>FORM>INPUT" CHARS="SEBA BADUY 2017 TRAILER 2"
EVENT TYPE=CLICK SELECTOR="HTML>BODY>HEADER>DIV>FORM>BUTTON>svg" BUTTON=0
WAIT SECONDS=3
EVENT TYPE=CLICK SELECTOR="HTML>BODY>MAIN>DIV>DIV:nth-of-type(2)>DIV>OL>LI>ARTICLE" BUTTON=0
EVENT TYPE=CLICK SELECTOR="HTML>BODY>MAIN>DIV>DIV:nth-of-type(2)>DIV>OL>LI:nth-of-type(2)>ARTICLE>A" BUTTON=0
EVENT TYPE=CLICK SELECTOR="#vid_v1x0sxw>DIV>DIV" BUTTON=0
WAIT SECONDS=80
REFRESH
URL GOTO=https://rumble.com/
WAIT SECONDS=3
EVENT TYPE=MOUSEDOWN SELECTOR="HTML>BODY>HEADER>DIV>FORM>BUTTON>svg" BUTTON=0
EVENT TYPE=CLICK SELECTOR="HTML>BODY>HEADER>DIV>FORM>BUTTON>svg" BUTTON=0
EVENT TYPE=MOUSEDOWN SELECTOR="HTML>BODY>HEADER>DIV>FORM>INPUT" BUTTON=0
EVENT TYPE=CLICK SELECTOR="HTML>BODY>HEADER>DIV>FORM>INPUT" BUTTON=0
EVENT TYPE=KEYPRESS SELECTOR="HTML>BODY>HEADER>DIV>FORM>INPUT" KEY=20
EVENTS TYPE=KEYPRESS SELECTOR="HTML>BODY>HEADER>DIV>FORM>INPUT" CHARS="ELITE PASS"
EVENT TYPE=CLICK SELECTOR="HTML>BODY>HEADER>DIV>FORM>BUTTON>svg>path" BUTTON=0
WAIT SECONDS=3
EVENT TYPE=CLICK SELECTOR="HTML>BODY>MAIN>DIV>DIV:nth-of-type(2)>DIV>OL>LI>ARTICLE>A" BUTTON=0
EVENT TYPE=CLICK SELECTOR="#vid_v1wu2ko>DIV>DIV>svg>path" BUTTON=0
WAIT SECONDS=44
REFRESH
